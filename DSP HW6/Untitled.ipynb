# %%
import numpy as np
import scipy.signal as ss
from scipy.io import wavfile
import matplotlib.pyplot as plt
import pandas as pd
import random

# %%
samplerate, data = wavfile.read("input.wav")

# %%
data_left = []; data_right = []
for i in range(len(data)):
    data_left.append(data[i][0])
    data_right.append(data[i][1])

# %%
x=data_left[0:26]
print(x)
xu=[]
for i in range(2048):
    xu.append(0)
xu[0:-1:80]=x
xp=xu[0:960]
for i in range(1088): xp.append(0)

len(xp)
# Out:
# [60, 59, 60, 60, 67, 69, 71, 74, 69, 63, 61, 63, 61, 60, 56, 58, 56, 57, 59, 57, 52, 49, 52, 56, 50, 50]
# 2048

# %%
xp_fft=np.fft.fft(xp)
xp_fft[0:100]
# Out:
# array([ 776.          +0.j        ,  103.13477853-527.42907741j,
#         -83.38927003 -17.84991012j,   96.50057696-100.01357453j,
#         -16.85013036 -33.9539959j ,   82.37618637 -47.94374736j,
#         -13.99512557 -42.65844925j,   69.61893364  -3.5668981j ,
#           5.24166963 -56.91698606j,   35.10351481 +20.85476073j,
#          30.33724815 -40.2313478j ,   21.0852136  +27.30197974j,
#          53.40183739 -27.67685665j,    5.03717839 +17.99609673j,
#          64.91306026  -4.60051767j,   -1.71528847  +1.37396378j,
#          59.17157288 +22.12489168j,   -2.84536655  -6.30275662j,
#          50.6157447  +62.99784014j,   27.53481139 -16.01957304j,
#          20.49284267 +83.12300134j,   59.89382504  +2.18091329j,
#          -4.42350595+101.87110902j,   94.93155627 +18.21972228j,
#        -159.52749891+204.26136409j,  464.53749998+502.13395582j,
#         626.31397122-383.23297809j, -128.2222475 -329.94137922j,
# ...

# %%
xp_fft_ifft=np.fft.ifft(xp_fft)
xp_fft_ifft[0:100]
# Out:
# array([ 6.00000000e+01+4.44089210e-16j,  0.00000000e+00+0.00000000e+00j,
#         0.00000000e+00+0.00000000e+00j,  0.00000000e+00+0.00000000e+00j,
#         0.00000000e+00+0.00000000e+00j,  0.00000000e+00+0.00000000e+00j,
#         0.00000000e+00+0.00000000e+00j,  0.00000000e+00+0.00000000e+00j,
#         0.00000000e+00+0.00000000e+00j,  0.00000000e+00+0.00000000e+00j,
#         0.00000000e+00+0.00000000e+00j,  0.00000000e+00+0.00000000e+00j,
#         0.00000000e+00+0.00000000e+00j,  0.00000000e+00+0.00000000e+00j,
#         0.00000000e+00+0.00000000e+00j,  0.00000000e+00+0.00000000e+00j,
#         3.95577614e-16+1.82187062e-16j,  0.00000000e+00+0.00000000e+00j,
#         0.00000000e+00+0.00000000e+00j,  0.00000000e+00+0.00000000e+00j,
#         0.00000000e+00+0.00000000e+00j,  0.00000000e+00+0.00000000e+00j,
#         0.00000000e+00+0.00000000e+00j,  0.00000000e+00+0.00000000e+00j,
#         0.00000000e+00+0.00000000e+00j,  0.00000000e+00+0.00000000e+00j,
# ...

# %%
x = data_left # get the left channel data
xx = np.zeros(2**(int(np.log2(len(x))+1)))
xx[0:len(x)]=x
len(xx)
plt.plot(x)

# %%
Xu=np.fft.fft(xu)
plt.plot(abs(Xu))

# %%
Xu[1:100]
# Out:
# array([190.40622978-3.51641452e+03j, 492.86440416-7.18387237e+02j,
#         46.55157096-6.59216382e+02j,  54.06162257-3.28807560e+02j,
#        -40.25148653-4.29295968e+02j, -84.48082327-3.12312873e+02j,
#         -1.64623352-3.26869053e+02j,  80.67488258-3.03874297e+02j,
#         45.91065121-1.49131162e+02j,  29.36474508-1.33740477e+02j,
#         54.45472223-1.53729881e+02j,  85.40792707-1.42599300e+02j,
#         64.34656785-1.15066939e+02j,  82.83999863-1.06245755e+02j,
#         61.05711194-7.42070559e+01j,  86.40821842-9.91922534e+01j,
#         37.83511106-9.01942875e+01j, 103.41529119-1.51178093e+02j,
#         51.22239736-1.11667361e+02j,  81.98935688-8.22726445e+01j,
#         66.82433783-5.53369214e+01j,  94.51374876-5.18184105e+01j,
#         65.22790307-4.36861361e+01j,  48.60808149-6.31810054e+01j,
#         59.        +1.90000000e+01j,  60.30400884-4.14315700e+01j,
#         49.5718623 -8.59090711e+01j,  74.68675366-4.02604931e+01j,
# ...

# %%
X=np.fft.fft(xx)
plt.plot(abs(X))
#X=np.fft.fftshift(X)
#plt.plot(abs(X))

# %%
np.fft.ifft(X)
plt.plot(x)
